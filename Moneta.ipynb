# %%
# You can load traces in two ways.  Paste the following into your jupyter notebook to open a file chooser.
from moneta.main import show_trace, select_trace
show_trace("./trace_0.hdf5")
# Out:
# error name 'index' is not defined
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/vaex/scopes.py in evaluate(self, expression, out)
#      96             # logger.debug("try avoid evaluating: %s", expression)
# ---> 97             result = self[expression]
#      98         except KeyError:
#
# /opt/conda/lib/python3.7/site-packages/vaex/scopes.py in __getitem__(self, variable)
#     143             if variable not in self.values:
# --> 144                 raise KeyError("Unknown variables or column: %r" % (variable,))
#     145
#
# KeyError: "Unknown variables or column: 'index'"
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in dtype(self, expression, internal)
#    2030             try:
# -> 2031                 data = self.evaluate(expression, 0, 1, filtered=False, internal=True, parallel=False)
#    2032             except:
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in evaluate(self, expression, i1, i2, out, selection, filtered, internal, parallel, chunk_size)
#    5119         else:
# -> 5120             return self._evaluate_implementation(expression, i1=i1, i2=i2, out=out, selection=selection, filtered=filtered, internal=internal, parallel=parallel, chunk_size=chunk_size)
#    5121
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in _evaluate_implementation(self, expression, i1, i2, out, selection, filtered, internal, parallel, chunk_size, raw)
#    5286                     scope.buffers[expression] = out
# -> 5287                 value = scope.evaluate(expression)
#    5288                 if isinstance(value, ColumnString) and not internal:
#
# /opt/conda/lib/python3.7/site-packages/vaex/scopes.py in evaluate(self, expression, out)
#     102             # eval("def f(")
# --> 103             result = eval(expression, expression_namespace, self)
#     104             self.values[expression] = result
#
# <string> in <module>
#
# NameError: name 'index' is not defined
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/vaex/scopes.py in evaluate(self, expression, out)
#      96             # logger.debug("try avoid evaluating: %s", expression)
# ---> 97             result = self[expression]
#      98         except KeyError:
#
# /opt/conda/lib/python3.7/site-packages/vaex/scopes.py in __getitem__(self, variable)
#     143             if variable not in self.values:
# --> 144                 raise KeyError("Unknown variables or column: %r" % (variable,))
#     145
#
# KeyError: "Unknown variables or column: 'index'"
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-27d5e3310d19> in <module>
#       1 # You can load traces in two ways.  Paste the following into your jupyter notebook to open a file chooser.
#       2 from moneta.main import show_trace, select_trace
# ----> 3 show_trace("./trace_0.hdf5")
#
# /cse142L/CSE141pp-Tool-Moneta/moneta/moneta/exports.py in show_trace(trace_path, zoom_access, zoom_address)
#      21 def show_trace(trace_path, zoom_access=None, zoom_address=None):
#      22     model = Moneta()
# ---> 23     err_message = model.load_trace(*os.path.split(trace_path))
#      24
#      25     if err_message:
#
# /cse142L/CSE141pp-Tool-Moneta/moneta/moneta/model.py in load_trace(self, path, trace_name)
#      20         meta_path = f'{path}/{raw_trace_name}{META_FILE_END}'
#      21
# ---> 22         self.curr_trace = Trace(trace_name, trace_path, tag_path, meta_path)
#      23         return self.curr_trace.err_message
#      24
#
# /cse142L/CSE141pp-Tool-Moneta/moneta/moneta/trace.py in __init__(self, name, trace_path, tag_path, meta_path)
#      70             return
#      71
# ---> 72         self.init_df()
#      73         self.retrieve_meta_data()
#      74         self.legend_state = None
#
# /cse142L/CSE141pp-Tool-Moneta/moneta/moneta/trace.py in init_df(self)
#      98     def init_df(self):
#      99         self.df = vaex.open(self.trace_path)
# --> 100         self.x_lim = [self.df[INDEX].min()[()], self.df[INDEX].max()[()] + 1]
#     101         self.y_lim = [self.df[ADDRESS].min()[()], self.df[ADDRESS].max()[()]+1]
#     102
#
# /opt/conda/lib/python3.7/site-packages/vaex/expression.py in min(self, binby, limits, shape, selection, delay, progress)
#     524         del kwargs['self']
#     525         kwargs['expression'] = self.expression
# --> 526         return self.ds.min(**kwargs)
#     527
#     528     def max(self, binby=[], limits=None, shape=default_shape, selection=False, delay=False, progress=None):
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in min(self, expression, binby, limits, shape, selection, delay, progress, edges)
#    1233         :return: {return_stat_scalar}, the last dimension is of shape (2)
#    1234         """
# -> 1235         return self._compute_agg('min', expression, binby, limits, shape, selection, delay, edges, progress)
#    1236         @delayed
#    1237         def finish(result):
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in _compute_agg(self, name, expression, binby, limits, shape, selection, delay, edges, progress, extra_expressions)
#     684         stats = [compute(expression, grid, selection=selection, edges=edges, progressbar=progressbar) for expression in expressions]
#     685         var = finish(*stats)
# --> 686         return self._delay(delay, var)
#     687
#     688     @docsubst
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in _delay(self, delay, task, progressbar)
#    1422     def _delay(self, delay, task, progressbar=False):
#    1423         if task.isRejected:
# -> 1424             task.get()
#    1425         if delay:
#    1426             return task
#
# /opt/conda/lib/python3.7/site-packages/aplus/__init__.py in get(self, timeout)
#     168             return self._value
#     169         else:
# --> 170             raise self._reason
#     171
#     172     def wait(self, timeout=None):
#
# /opt/conda/lib/python3.7/site-packages/vaex/promise.py in callAndReject(r)
#     108             try:
#     109                 if aplus._isFunction(failure):
# --> 110                     ret.fulfill(failure(r))
#     111                 else:
#     112                     ret.reject(r)
#
# /opt/conda/lib/python3.7/site-packages/vaex/delayed.py in error(exc)
#      69         def error(exc):
#      70             print("error", exc)
# ---> 71             raise exc
#      72         return allarguments.then(call, error)
#      73     return wrapped
#
# /opt/conda/lib/python3.7/site-packages/vaex/promise.py in callAndFulfill(v)
#      93             try:
#      94                 if aplus._isFunction(success):
# ---> 95                     ret.fulfill(success(v))
#      96                 else:
#      97                     ret.fulfill(v)
#
# /opt/conda/lib/python3.7/site-packages/vaex/delayed.py in call(_)
#      65             kwargs_real = {key: promise.get() for key, promise in key_promise}
#      66             args_real = list([promise.get() for promise in arg_promises])
# ---> 67             return f(*args_real, **kwargs_real)
#      68
#      69         def error(exc):
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in compute(expression, grid, selection, edges, progressbar)
#     669                         agg = vaex.agg.aggregates[name](expression, selection=selection)
#     670                 task = self._get_task_agg(grid)
# --> 671                 agg_subtask = agg.add_operations(task, edges=edges)
#     672                 progressbar.add_task(task, "%s for %s" % (name, expression))
#     673                 @delayed
#
# /opt/conda/lib/python3.7/site-packages/vaex/agg.py in add_operations(self, agg_task, edges, **kwargs)
#      48
#      49     def add_operations(self, agg_task, edges=True, **kwargs):
# ---> 50         value = agg_task.add_aggregation_operation(self, edges=edges, selection=self.selection, **kwargs)
#      51         @vaex.delayed
#      52         def finish(value):
#
# /opt/conda/lib/python3.7/site-packages/vaex/tasks.py in add_aggregation_operation(self, aggregator_descriptor, selection, edges)
#     505             return [aggregator_descriptor._create_operation(self.df, self.grids[thread_index]) for selection in selections]
#     506         task = Task(self.df, [], "--")
# --> 507         self.aggregations.append((aggregator_descriptor, selections, [create_aggregator(i) for i in range(self.nthreads)], selection_waslist, edges, task))
#     508         self.expressions_all.extend(aggregator_descriptor.expressions)
#     509         self.expressions_all = list(set(self.expressions_all))
#
# /opt/conda/lib/python3.7/site-packages/vaex/tasks.py in <listcomp>(.0)
#     505             return [aggregator_descriptor._create_operation(self.df, self.grids[thread_index]) for selection in selections]
#     506         task = Task(self.df, [], "--")
# --> 507         self.aggregations.append((aggregator_descriptor, selections, [create_aggregator(i) for i in range(self.nthreads)], selection_waslist, edges, task))
#     508         self.expressions_all.extend(aggregator_descriptor.expressions)
#     509         self.expressions_all = list(set(self.expressions_all))
#
# /opt/conda/lib/python3.7/site-packages/vaex/tasks.py in create_aggregator(thread_index)
#     503         def create_aggregator(thread_index):
#     504             # for each selection, we have a separate aggregator, sharing the grid and binners
# --> 505             return [aggregator_descriptor._create_operation(self.df, self.grids[thread_index]) for selection in selections]
#     506         task = Task(self.df, [], "--")
#     507         self.aggregations.append((aggregator_descriptor, selections, [create_aggregator(i) for i in range(self.nthreads)], selection_waslist, edges, task))
#
# /opt/conda/lib/python3.7/site-packages/vaex/tasks.py in <listcomp>(.0)
#     503         def create_aggregator(thread_index):
#     504             # for each selection, we have a separate aggregator, sharing the grid and binners
# --> 505             return [aggregator_descriptor._create_operation(self.df, self.grids[thread_index]) for selection in selections]
#     506         task = Task(self.df, [], "--")
#     507         self.aggregations.append((aggregator_descriptor, selections, [create_aggregator(i) for i in range(self.nthreads)], selection_waslist, edges, task))
#
# /opt/conda/lib/python3.7/site-packages/vaex/agg.py in _create_operation(self, df, grid)
#      59             self.dtype_out = np.dtype('int64')
#      60         else:
# ---> 61             self.dtype_in = df[str(self.expressions[0])].dtype
#      62             self.dtype_out = self.dtype_in
#      63             if self.short_name == "count":
#
# /opt/conda/lib/python3.7/site-packages/vaex/expression.py in dtype(self)
#     252     @property
#     253     def dtype(self):
# --> 254         return self.ds.dtype(self.expression)
#     255
#     256     @property
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in dtype(self, expression, internal)
#    2031                 data = self.evaluate(expression, 0, 1, filtered=False, internal=True, parallel=False)
#    2032             except:
# -> 2033                 data = self.evaluate(expression, 0, 1, filtered=True, internal=True, parallel=False)
#    2034             dtype = data.dtype
#    2035         if not internal:
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in evaluate(self, expression, i1, i2, out, selection, filtered, internal, parallel, chunk_size)
#    5118             return self.evaluate_iterator(expression, s1=i1, s2=i2, out=out, selection=selection, filtered=filtered, internal=internal, parallel=parallel, chunk_size=chunk_size)
#    5119         else:
# -> 5120             return self._evaluate_implementation(expression, i1=i1, i2=i2, out=out, selection=selection, filtered=filtered, internal=internal, parallel=parallel, chunk_size=chunk_size)
#    5121
#    5122     def evaluate_iterator(self, expression, s1=None, s2=None, out=None, selection=None, filtered=True, internal=None, parallel=True, chunk_size=None, prefetch=True):
#
# /opt/conda/lib/python3.7/site-packages/vaex/dataframe.py in _evaluate_implementation(self, expression, i1, i2, out, selection, filtered, internal, parallel, chunk_size, raw)
#    5285                 if out is not None:
#    5286                     scope.buffers[expression] = out
# -> 5287                 value = scope.evaluate(expression)
#    5288                 if isinstance(value, ColumnString) and not internal:
#    5289                     value = value.to_numpy()
#
# /opt/conda/lib/python3.7/site-packages/vaex/scopes.py in evaluate(self, expression, out)
#     101             # logger.debug("in eval")
#     102             # eval("def f(")
# --> 103             result = eval(expression, expression_namespace, self)
#     104             self.values[expression] = result
#     105             # if out is not None:
#
# <string> in <module>
#
# NameError: name 'index' is not defined
